# %%
import pandas as pd

# Load the data
file_path = "../data/MachineLearningRating_v3.txt"  # Update this if the file is in a different folder
df = pd.read_csv(file_path, delimiter='|')

# Preview
print(df.shape)
print(df.head())
# Out:
# C:\Users\ads\AppData\Local\Temp\ipykernel_7228\1778012136.py:5: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter='|')
# (1000098, 52)
#    UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0               145249     12827  2015-03-01 00:00:00             True
# 1               145249     12827  2015-05-01 00:00:00             True
# 2               145249     12827  2015-07-01 00:00:00             True
# 3               145255     12827  2015-05-01 00:00:00             True
# 4               145255     12827  2015-07-01 00:00:00             True
#
#   Citizenship          LegalType Title Language                 Bank  \
# 0              Close Corporation    Mr  English  First National Bank
# 1              Close Corporation    Mr  English  First National Bank
# 2              Close Corporation    Mr  English  First National Bank
# ...

# %% [markdown]
# Data Summarization

# %%
# Check basic info
df.info()

# Descriptive stats for numerical features
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
# ...

# %% [markdown]
# Check Data Types

# %%
# View types
df.dtypes
# Out:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# kilowatts                   float64
# ...

# %% [markdown]
# Missing Values

# %%
# Count missing values
missing = df.isnull().sum()
missing[missing > 0]
# Out:
# Bank                        145961
# AccountType                  40232
# MaritalStatus                 8259
# Gender                        9536
# mmcode                         552
# VehicleType                    552
# make                           552
# Model                          552
# Cylinders                      552
# cubiccapacity                  552
# kilowatts                      552
# bodytype                       552
# NumberOfDoors                  552
# VehicleIntroDate               552
# CustomValueEstimate         779642
# CapitalOutstanding               2
# NewVehicle                  153295
# WrittenOff                  641901
# Rebuilt                     641901
# Converted                   641901
# CrossBorder                 999400
# NumberOfVehiclesInFleet    1000098
# dtype: int64

# %% [markdown]
# Convert Dates

# %%
# Convert TransactionMonth to datetime
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'])

# %% [markdown]
# Analyze Key Variables

# %% [markdown]
# Loss Ratio

# %%
df['LossRatio'] = df['TotalClaims'] / df['TotalPremium']

# %%
# Loss ratio by Province
df.groupby('Province')['LossRatio'].mean().sort_values()

# Loss ratio by VehicleType
df.groupby('VehicleType')['LossRatio'].mean().sort_values()

# Loss ratio by Gender
df.groupby('Gender')['LossRatio'].mean().sort_values()
# Out:
# Gender
# Female           inf
# Male             inf
# Not specified    NaN
# Name: LossRatio, dtype: float64

# %% [markdown]
#  Visualizations

# %% [markdown]
# 1. Distribution of TotalPremium and TotalClaims

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['TotalPremium'], kde=True)
plt.title("Distribution of TotalPremium")
plt.show()

sns.histplot(df['TotalClaims'], kde=True)
plt.title("Distribution of TotalClaims")
plt.show()

# %% [markdown]
# 2. Monthly Trends

# %%
monthly_trends = df.groupby(df['TransactionMonth'].dt.to_period('M'))[['TotalPremium', 'TotalClaims']].sum()
monthly_trends.plot(kind='line', marker='o')
plt.title("Monthly Total Premium vs Claims")
plt.show()

# %% [markdown]
# 3. Box Plot to Detect Outliers

# %%
sns.boxplot(data=df[['TotalPremium', 'TotalClaims']])
plt.title("Outlier Detection in Premiums and Claims")
plt.show()

# %% [markdown]
# Statistical Insight

# %%
# Correlation
corr = df[['TotalPremium', 'TotalClaims', 'LossRatio']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
#  Loss Ratio by Province (Bar Plot)

# %%
plt.figure(figsize=(10, 5))
df.groupby('Province')['LossRatio'].mean().sort_values().plot(kind='barh', color='skyblue')
plt.title("Average Loss Ratio by Province")
plt.xlabel("Loss Ratio")
plt.ylabel("Province")
plt.tight_layout()
plt.show()
# Out:
# c:\Users\ads\Desktop\Week 3\insurance-risk-analytics\venv\Lib\site-packages\matplotlib\transforms.py:2436: RuntimeWarning: invalid value encountered in dot
#   return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# c:\Users\ads\Desktop\Week 3\insurance-risk-analytics\venv\Lib\site-packages\matplotlib\transforms.py:2436: RuntimeWarning: invalid value encountered in dot
#   return Affine2D(np.dot(self._b.get_affine().get_matrix(),

# %% [markdown]
# Loss Ratio by Gender

# %%
sns.barplot(data=df, x='Gender', y='LossRatio', estimator='mean', ci=None)
plt.title("Average Loss Ratio by Gender")
plt.ylabel("Loss Ratio")
plt.xlabel("Gender")
plt.show()
# Out:
# C:\Users\ads\AppData\Local\Temp\ipykernel_7228\2439351262.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Gender', y='LossRatio', estimator='mean', ci=None)

# %% [markdown]
# Loss Ratio by VehicleType

# %%
plt.figure(figsize=(10, 6))
df.groupby('VehicleType')['LossRatio'].mean().sort_values().plot(kind='bar', color='salmon')
plt.title("Loss Ratio by Vehicle Type")
plt.ylabel("Loss Ratio")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\ads\Desktop\Week 3\insurance-risk-analytics\venv\Lib\site-packages\matplotlib\transforms.py:2436: RuntimeWarning: invalid value encountered in dot
#   return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# c:\Users\ads\Desktop\Week 3\insurance-risk-analytics\venv\Lib\site-packages\matplotlib\transforms.py:2436: RuntimeWarning: invalid value encountered in dot
#   return Affine2D(np.dot(self._b.get_affine().get_matrix(),
